# %% [markdown]
# # Soal 11.26
#
# Program Gauss-Seidel berdasarkan Fig. 11.6 dan diuji pada Example 11.3.

# %%
import numpy as np
np.set_printoptions(precision=6, suppress=True)

def gauss_seidel(A, b, x0=None, es=5.0, max_iter=100, lam=1.0):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)
    n = len(b)
    x = np.zeros(n) if x0 is None else np.array(x0, dtype=float)
    rows = []
    for it in range(1, max_iter + 1):
        old = x.copy()
        for i in range(n):
            raw = (b[i] - np.dot(A[i, :i], x[:i]) - np.dot(A[i, i + 1:], old[i + 1:])) / A[i, i]
            x[i] = lam * raw + (1 - lam) * old[i]
        ea = np.full(n, np.nan)
        mask = x != 0
        ea[mask] = np.abs((x[mask] - old[mask]) / x[mask]) * 100
        rows.append([it, *x, np.nanmax(ea)])
        if np.nanmax(ea) < es:
            break
    return x, np.array(rows)

def jacobi(A, b, x0=None, es=5.0, max_iter=100):
    A = np.array(A, dtype=float)
    b = np.array(b, dtype=float)
    n = len(b)
    x = np.zeros(n) if x0 is None else np.array(x0, dtype=float)
    rows = []
    for it in range(1, max_iter + 1):
        old = x.copy()
        for i in range(n):
            x[i] = (b[i] - np.dot(A[i, :i], old[:i]) - np.dot(A[i, i + 1:], old[i + 1:])) / A[i, i]
        ea = np.full(n, np.nan)
        mask = x != 0
        ea[mask] = np.abs((x[mask] - old[mask]) / x[mask]) * 100
        rows.append([it, *x, np.nanmax(ea)])
        if np.nanmax(ea) < es:
            break
    return x, np.array(rows)

A = np.array([[3, -0.1, -0.2], [0.1, 7, -0.3], [0.3, -0.2, 10]], float)
b = np.array([7.85, -19.3, 71.4], float)
x, hist = gauss_seidel(A, b, es=0.01, max_iter=100)
print("x =", x)
print("jumlah iterasi =", len(hist))
print("histori akhir =", hist[-5:])
print("solusi eksak =", np.linalg.solve(A, b))
# Out:
# x = [ 3.  -2.5  7. ]
# jumlah iterasi = 4
# histori akhir = [[  1.         2.616667  -2.794524   7.00561  100.      ]
#  [  2.         2.990557  -2.499625   7.000291  12.50235 ]
#  [  3.         3.000032  -2.499988   6.999999   0.315843]
#  [  4.         3.        -2.5        7.         0.001052]]
# solusi eksak = [ 3.  -2.5  7. ]

# %% [markdown]
# Hasil mendekati solusi Example 11.3, yaitu `[3, -2.5, 7]`.
